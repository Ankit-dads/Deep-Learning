# %%
print('hello')
# Out:
# hello

# %%
import transformers

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\__init__.py:288
#     284                     raise err
#     286         kernel32.SetErrorMode(prev_error_mode)
# --> 288     _load_dll_libraries()
#     289     del _load_dll_libraries
#     292 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     293     # Libraries can either be in
#     294     # path/nvidia/lib_folder/lib or
#     295     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     296     # path/lib_folder/lib
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torch\__init__.py:271, in _load_dll_libraries()
#     267     err = ctypes.WinError(last_error)
#     268     err.strerror += (
#     269         f' Error loading "{dll}" or one of its dependencies.'
#     270     )
# ...

# %%
print(transformers.__version__)
# Out:
# 5.14.0

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
result = classifier('i love this movie so much')
print(result)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998809099197388}]

# %%
import sentencepiece

# %%
result = classifier("my friend is a gay will he admit it")
print(result)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.6767446398735046}]

# %%
from transformers import pipeline

# %%
summarizer = pipeline('summarization',model = 'facebook/bart-large-cnn')
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--facebook--bart-large-cnn. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 from transformers import pipeline
# ----> 3 summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\pipelines\__init__.py:974, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     967         pipeline_class = get_class_from_dynamic_module(
#     968             class_ref,
#     969             model,
#     970             code_revision=code_revision,
#     971             **hub_kwargs,
#     972         )
#     973 else:
# --> 974     normalized_task, targeted_task, task_options = check_task(task)
#     975     if pipeline_class is None:
# ...

# %%
translater = pipeline("text-to-audio")
result = translater('i want to learn french')

print(result)

# %%
from transformers import pipeline

translater = pipeline("text-to-audio")
result = translater('i want to learn french')

print(result)
# Out:
# [transformers] No model was supplied, defaulted to suno/bark-small and revision 1dbd7a1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/8.80k [00:00<?, ?B/s]
# C:\Users\ASUS\AppData\Roaming\Python\Python313\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--suno--bark-small. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
from transformers import pipeline

translater = pipeline("text-to-audio")
result = translater('i want to learn french')

print(result)
# Out:
# [transformers] No model was supplied, defaulted to suno/bark-small and revision 1dbd7a1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B / 1.68GB
# pytorch_model.bin: downloading bytes:           |  0.00B
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from transformers import pipeline
# ----> 3 translater = pipeline("text-to-audio")
#       4 result = translater('i want to learn french')
#       6 print(result)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\pipelines\__init__.py:1033, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
# ...
