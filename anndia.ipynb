# %%
# importing dataset and libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('diabetes.csv')
df.head()
df.isnull().sum()
df.duplicated()


# DATA IS CLEANED AND NOT HAVING ANY NULL AND DUPLICATED VALUES
(df['Glucose']==0).sum() # to check that is the dataset have any null value filled with zero

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())

# this dataset have values which are filled with zero
# so we have to fill them with median becuase median is not effected by outliers while mean is

zero_col = ['Glucose','BloodPressure','SkinThickness','BMI','Insulin']

for col in zero_col:
    df[col] = df[col].replace(0, df[col].median())

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())
# All the values are filled with median 
df.describe()

# splitting data into input feature and output feature
x = df.drop('Outcome',axis=1)
y = df['Outcome']


# Train Test Split

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=24,test_size=0.2)

print(x_train.shape)
print(y_train.shape)

# performing standard scalar
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# building ANN architecture 

model = Sequential()
model.add(Dense(16,activation='relu',input_shape=(8,)))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()

# compile the model 

model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# training the model;

history = model.fit(x_train,y_train,
                    epochs = 100,
                    batch_size = 32,
                    validation_split = 0.2,
                    verbose = 1
                    )



from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# Get predictions
y_pred = (model.predict(x_test) > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Diabetes', 'Diabetes'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png', dpi=150)

# Classification Report
print(classification_report(y_test, y_pred, target_names=['No Diabetes', 'Diabetes']))
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# BMI               11
# Insulin          374
# dtype: int64
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# BMI              0
# Insulin          0
# dtype: int64
# (614, 8)
# (614,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 289
# Trainable params: 289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 3s 19ms/step - loss: 0.6543 - accuracy: 0.6069 - val_loss: 0.6464 - val_accuracy: 0.6585
# Epoch 2/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6116 - accuracy: 0.6477 - val_loss: 0.6309 - val_accuracy: 0.6667
# Epoch 3/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5792 - accuracy: 0.6701 - val_loss: 0.6193 - val_accuracy: 0.6667
# Epoch 4/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5541 - accuracy: 0.6965 - val_loss: 0.6112 - val_accuracy: 0.6667
# Epoch 5/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5331 - accuracy: 0.7108 - val_loss: 0.6092 - val_accuracy: 0.6667
# Epoch 6/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.5138 - accuracy: 0.7413 - val_loss: 0.6031 - val_accuracy: 0.6667
# Epoch 7/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4991 - accuracy: 0.7536 - val_loss: 0.5983 - val_accuracy: 0.6748
# Epoch 8/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4865 - accuracy: 0.7556 - val_loss: 0.5942 - val_accuracy: 0.6911
# Epoch 9/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4752 - accuracy: 0.7637 - val_loss: 0.5879 - val_accuracy: 0.6992
# Epoch 10/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4657 - accuracy: 0.7760 - val_loss: 0.5830 - val_accuracy: 0.7073
# Epoch 11/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4582 - accuracy: 0.7821 - val_loss: 0.5788 - val_accuracy: 0.7073
# Epoch 12/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4521 - accuracy: 0.7902 - val_loss: 0.5776 - val_accuracy: 0.7236
# Epoch 13/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4467 - accuracy: 0.7943 - val_loss: 0.5726 - val_accuracy: 0.7236
# Epoch 14/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4419 - accuracy: 0.8045 - val_loss: 0.5718 - val_accuracy: 0.7317
# Epoch 15/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4376 - accuracy: 0.8106 - val_loss: 0.5731 - val_accuracy: 0.7317
# Epoch 16/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4342 - accuracy: 0.8086 - val_loss: 0.5699 - val_accuracy: 0.7317
# Epoch 17/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4309 - accuracy: 0.8167 - val_loss: 0.5701 - val_accuracy: 0.7317
# Epoch 18/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4279 - accuracy: 0.8167 - val_loss: 0.5652 - val_accuracy: 0.7317
# Epoch 19/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4259 - accuracy: 0.8126 - val_loss: 0.5629 - val_accuracy: 0.7317
# Epoch 20/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4235 - accuracy: 0.8167 - val_loss: 0.5656 - val_accuracy: 0.7317
# Epoch 21/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4212 - accuracy: 0.8147 - val_loss: 0.5695 - val_accuracy: 0.7317
# Epoch 22/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4189 - accuracy: 0.8187 - val_loss: 0.5685 - val_accuracy: 0.7317
# Epoch 23/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4174 - accuracy: 0.8208 - val_loss: 0.5717 - val_accuracy: 0.7317
# Epoch 24/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4155 - accuracy: 0.8167 - val_loss: 0.5637 - val_accuracy: 0.7317
# Epoch 25/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4136 - accuracy: 0.8167 - val_loss: 0.5691 - val_accuracy: 0.7317
# Epoch 26/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4117 - accuracy: 0.8187 - val_loss: 0.5735 - val_accuracy: 0.7317
# Epoch 27/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4107 - accuracy: 0.8167 - val_loss: 0.5696 - val_accuracy: 0.7317
# Epoch 28/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4097 - accuracy: 0.8126 - val_loss: 0.5619 - val_accuracy: 0.7398
# Epoch 29/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4071 - accuracy: 0.8126 - val_loss: 0.5668 - val_accuracy: 0.7317
# Epoch 30/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4058 - accuracy: 0.8126 - val_loss: 0.5684 - val_accuracy: 0.7317
# Epoch 31/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4044 - accuracy: 0.8126 - val_loss: 0.5671 - val_accuracy: 0.7317
# Epoch 32/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4029 - accuracy: 0.8167 - val_loss: 0.5688 - val_accuracy: 0.7398
# Epoch 33/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4014 - accuracy: 0.8147 - val_loss: 0.5665 - val_accuracy: 0.7398
# Epoch 34/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4002 - accuracy: 0.8126 - val_loss: 0.5630 - val_accuracy: 0.7317
# Epoch 35/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3995 - accuracy: 0.8167 - val_loss: 0.5697 - val_accuracy: 0.7236
# Epoch 36/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3980 - accuracy: 0.8147 - val_loss: 0.5647 - val_accuracy: 0.7154
# Epoch 37/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3971 - accuracy: 0.8106 - val_loss: 0.5615 - val_accuracy: 0.7236
# Epoch 38/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3957 - accuracy: 0.8147 - val_loss: 0.5634 - val_accuracy: 0.7154
# Epoch 39/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3947 - accuracy: 0.8167 - val_loss: 0.5624 - val_accuracy: 0.7154
# Epoch 40/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3938 - accuracy: 0.8187 - val_loss: 0.5641 - val_accuracy: 0.7154
# Epoch 41/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3928 - accuracy: 0.8167 - val_loss: 0.5612 - val_accuracy: 0.7154
# Epoch 42/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3921 - accuracy: 0.8147 - val_loss: 0.5608 - val_accuracy: 0.7236
# Epoch 43/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3907 - accuracy: 0.8167 - val_loss: 0.5656 - val_accuracy: 0.7236
# Epoch 44/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3898 - accuracy: 0.8187 - val_loss: 0.5625 - val_accuracy: 0.7236
# Epoch 45/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3892 - accuracy: 0.8167 - val_loss: 0.5588 - val_accuracy: 0.7236
# Epoch 46/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3879 - accuracy: 0.8187 - val_loss: 0.5631 - val_accuracy: 0.7236
# Epoch 47/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3875 - accuracy: 0.8187 - val_loss: 0.5569 - val_accuracy: 0.7317
# Epoch 48/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3865 - accuracy: 0.8187 - val_loss: 0.5638 - val_accuracy: 0.7236
# Epoch 49/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3859 - accuracy: 0.8187 - val_loss: 0.5599 - val_accuracy: 0.7317
# Epoch 50/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3851 - accuracy: 0.8208 - val_loss: 0.5626 - val_accuracy: 0.7317
# Epoch 51/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3845 - accuracy: 0.8208 - val_loss: 0.5586 - val_accuracy: 0.7317
# Epoch 52/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3836 - accuracy: 0.8208 - val_loss: 0.5645 - val_accuracy: 0.7236
# Epoch 53/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3827 - accuracy: 0.8208 - val_loss: 0.5666 - val_accuracy: 0.7236
# Epoch 54/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3825 - accuracy: 0.8228 - val_loss: 0.5684 - val_accuracy: 0.7317
# Epoch 55/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3810 - accuracy: 0.8228 - val_loss: 0.5553 - val_accuracy: 0.7317
# Epoch 56/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3804 - accuracy: 0.8126 - val_loss: 0.5522 - val_accuracy: 0.7317
# Epoch 57/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3802 - accuracy: 0.8167 - val_loss: 0.5536 - val_accuracy: 0.7317
# Epoch 58/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3790 - accuracy: 0.8126 - val_loss: 0.5659 - val_accuracy: 0.7317
# Epoch 59/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3785 - accuracy: 0.8208 - val_loss: 0.5645 - val_accuracy: 0.7317
# Epoch 60/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3785 - accuracy: 0.8187 - val_loss: 0.5703 - val_accuracy: 0.7317
# Epoch 61/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3769 - accuracy: 0.8208 - val_loss: 0.5596 - val_accuracy: 0.7317
# Epoch 62/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3771 - accuracy: 0.8167 - val_loss: 0.5652 - val_accuracy: 0.7317
# Epoch 63/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3760 - accuracy: 0.8147 - val_loss: 0.5629 - val_accuracy: 0.7317
# Epoch 64/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3759 - accuracy: 0.8147 - val_loss: 0.5627 - val_accuracy: 0.7317
# Epoch 65/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3748 - accuracy: 0.8208 - val_loss: 0.5612 - val_accuracy: 0.7317
# Epoch 66/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3740 - accuracy: 0.8167 - val_loss: 0.5606 - val_accuracy: 0.7317
# Epoch 67/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3733 - accuracy: 0.8167 - val_loss: 0.5599 - val_accuracy: 0.7317
# Epoch 68/100
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3731 - accuracy: 0.8187 - val_loss: 0.5563 - val_accuracy: 0.7398
# Epoch 69/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3728 - accuracy: 0.8167 - val_loss: 0.5579 - val_accuracy: 0.7398
# Epoch 70/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3718 - accuracy: 0.8187 - val_loss: 0.5566 - val_accuracy: 0.7317
# Epoch 71/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3717 - accuracy: 0.8167 - val_loss: 0.5587 - val_accuracy: 0.7317
# Epoch 72/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3706 - accuracy: 0.8167 - val_loss: 0.5594 - val_accuracy: 0.7398
# Epoch 73/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3702 - accuracy: 0.8187 - val_loss: 0.5536 - val_accuracy: 0.7398
# Epoch 74/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3700 - accuracy: 0.8187 - val_loss: 0.5535 - val_accuracy: 0.7398
# Epoch 75/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3704 - accuracy: 0.8208 - val_loss: 0.5399 - val_accuracy: 0.7398
# Epoch 76/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3692 - accuracy: 0.8187 - val_loss: 0.5555 - val_accuracy: 0.7398
# Epoch 77/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3686 - accuracy: 0.8187 - val_loss: 0.5553 - val_accuracy: 0.7398
# Epoch 78/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3678 - accuracy: 0.8208 - val_loss: 0.5553 - val_accuracy: 0.7398
# Epoch 79/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3671 - accuracy: 0.8208 - val_loss: 0.5536 - val_accuracy: 0.7317
# Epoch 80/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3668 - accuracy: 0.8208 - val_loss: 0.5487 - val_accuracy: 0.7398
# Epoch 81/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3662 - accuracy: 0.8228 - val_loss: 0.5484 - val_accuracy: 0.7317
# Epoch 82/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3661 - accuracy: 0.8208 - val_loss: 0.5530 - val_accuracy: 0.7317
# Epoch 83/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3651 - accuracy: 0.8248 - val_loss: 0.5549 - val_accuracy: 0.7317
# Epoch 84/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3653 - accuracy: 0.8248 - val_loss: 0.5420 - val_accuracy: 0.7317
# Epoch 85/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3650 - accuracy: 0.8269 - val_loss: 0.5417 - val_accuracy: 0.7317
# Epoch 86/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3640 - accuracy: 0.8248 - val_loss: 0.5544 - val_accuracy: 0.7317
# Epoch 87/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3631 - accuracy: 0.8248 - val_loss: 0.5457 - val_accuracy: 0.7317
# Epoch 88/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3624 - accuracy: 0.8228 - val_loss: 0.5526 - val_accuracy: 0.7317
# Epoch 89/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3619 - accuracy: 0.8228 - val_loss: 0.5520 - val_accuracy: 0.7317
# Epoch 90/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3618 - accuracy: 0.8269 - val_loss: 0.5489 - val_accuracy: 0.7317
# Epoch 91/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3617 - accuracy: 0.8248 - val_loss: 0.5432 - val_accuracy: 0.7317
# Epoch 92/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3610 - accuracy: 0.8228 - val_loss: 0.5458 - val_accuracy: 0.7317
# Epoch 93/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3598 - accuracy: 0.8248 - val_loss: 0.5575 - val_accuracy: 0.7317
# Epoch 94/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3598 - accuracy: 0.8248 - val_loss: 0.5455 - val_accuracy: 0.7317
# Epoch 95/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3593 - accuracy: 0.8269 - val_loss: 0.5438 - val_accuracy: 0.7317
# Epoch 96/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3587 - accuracy: 0.8248 - val_loss: 0.5529 - val_accuracy: 0.7317
# Epoch 97/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3582 - accuracy: 0.8269 - val_loss: 0.5491 - val_accuracy: 0.7317
# Epoch 98/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3574 - accuracy: 0.8248 - val_loss: 0.5515 - val_accuracy: 0.7317
# Epoch 99/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3567 - accuracy: 0.8269 - val_loss: 0.5516 - val_accuracy: 0.7317
# Epoch 100/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3563 - accuracy: 0.8310 - val_loss: 0.5525 - val_accuracy: 0.7317
# 5/5 [==============================] - 0s 884us/step
#               precision    recall  f1-score   support
#
#  No Diabetes       0.71      0.87      0.78        98
#     Diabetes       0.63      0.39      0.48        56
#
#     accuracy                           0.69       154
#    macro avg       0.67      0.63      0.63       154
# weighted avg       0.68      0.69      0.67       154

# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
# Out:
# 2.10.1
