# %%
# importing dataset and libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('diabetes.csv')
df.head()
df.isnull().sum()
df.duplicated()


# DATA IS CLEANED AND NOT HAVING ANY NULL AND DUPLICATED VALUES
(df['Glucose']==0).sum() # to check that is the dataset have any null value filled with zero

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())

# this dataset have values which are filled with zero
# so we have to fill them with median becuase median is not effected by outliers while mean is

zero_col = ['Glucose','BloodPressure','SkinThickness','BMI','Insulin']

for col in zero_col:
    df[col] = df[col].replace(0, df[col].median())

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())
# All the values are filled with median 
df.describe()

# splitting data into input feature and output feature
x = df.drop('Outcome',axis=1)
y = df['Outcome']


# Train Test Split

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=24,test_size=0.2)

print(x_train.shape)
print(y_train.shape)

# performing standard scalar
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# building ANN architecture 

model = Sequential()
model.add(Dense(16,activation='relu',input_shape=(8,)))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()

# compile the model 

model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# training the model;

history = model.fit(x_train,y_train,
                    epochs = 100,
                    batch_size = 32,
                    validation_split = 0.2,
                    verbose = 1
                    )



from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# Get predictions
y_pred = (model.predict(x_test) > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Diabetes', 'Diabetes'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png', dpi=150)

# Classification Report
print(classification_report(y_test, y_pred, target_names=['No Diabetes', 'Diabetes']))
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# BMI               11
# Insulin          374
# dtype: int64
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# BMI              0
# Insulin          0
# dtype: int64
# (614, 8)
# (614,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 289
# Trainable params: 289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 3s 23ms/step - loss: 0.6956 - accuracy: 0.5418 - val_loss: 0.6804 - val_accuracy: 0.5285
# Epoch 2/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6391 - accuracy: 0.6171 - val_loss: 0.6523 - val_accuracy: 0.6098
# Epoch 3/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5959 - accuracy: 0.6660 - val_loss: 0.6263 - val_accuracy: 0.6667
# Epoch 4/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5617 - accuracy: 0.6945 - val_loss: 0.6116 - val_accuracy: 0.6829
# Epoch 5/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5373 - accuracy: 0.7108 - val_loss: 0.6012 - val_accuracy: 0.6829
# Epoch 6/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5184 - accuracy: 0.7352 - val_loss: 0.5911 - val_accuracy: 0.6911
# Epoch 7/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5035 - accuracy: 0.7454 - val_loss: 0.5799 - val_accuracy: 0.7073
# Epoch 8/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4910 - accuracy: 0.7617 - val_loss: 0.5753 - val_accuracy: 0.7154
# Epoch 9/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4800 - accuracy: 0.7658 - val_loss: 0.5671 - val_accuracy: 0.7236
# Epoch 10/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4716 - accuracy: 0.7658 - val_loss: 0.5591 - val_accuracy: 0.7480
# Epoch 11/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4625 - accuracy: 0.7739 - val_loss: 0.5569 - val_accuracy: 0.7398
# Epoch 12/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4561 - accuracy: 0.7821 - val_loss: 0.5572 - val_accuracy: 0.7561
# Epoch 13/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4500 - accuracy: 0.7902 - val_loss: 0.5475 - val_accuracy: 0.7561
# Epoch 14/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4437 - accuracy: 0.7902 - val_loss: 0.5504 - val_accuracy: 0.7561
# Epoch 15/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4391 - accuracy: 0.8045 - val_loss: 0.5522 - val_accuracy: 0.7642
# Epoch 16/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4347 - accuracy: 0.8065 - val_loss: 0.5511 - val_accuracy: 0.7398
# Epoch 17/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4311 - accuracy: 0.8126 - val_loss: 0.5493 - val_accuracy: 0.7398
# Epoch 18/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4274 - accuracy: 0.8147 - val_loss: 0.5448 - val_accuracy: 0.7480
# Epoch 19/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4238 - accuracy: 0.8086 - val_loss: 0.5402 - val_accuracy: 0.7398
# Epoch 20/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4209 - accuracy: 0.8106 - val_loss: 0.5423 - val_accuracy: 0.7317
# Epoch 21/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4176 - accuracy: 0.8147 - val_loss: 0.5464 - val_accuracy: 0.7317
# Epoch 22/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4153 - accuracy: 0.8147 - val_loss: 0.5399 - val_accuracy: 0.7398
# Epoch 23/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4136 - accuracy: 0.8167 - val_loss: 0.5506 - val_accuracy: 0.7561
# Epoch 24/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4103 - accuracy: 0.8187 - val_loss: 0.5425 - val_accuracy: 0.7561
# Epoch 25/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4084 - accuracy: 0.8167 - val_loss: 0.5394 - val_accuracy: 0.7561
# Epoch 26/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4063 - accuracy: 0.8208 - val_loss: 0.5443 - val_accuracy: 0.7561
# Epoch 27/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4045 - accuracy: 0.8228 - val_loss: 0.5485 - val_accuracy: 0.7561
# Epoch 28/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4029 - accuracy: 0.8248 - val_loss: 0.5472 - val_accuracy: 0.7561
# Epoch 29/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4012 - accuracy: 0.8248 - val_loss: 0.5498 - val_accuracy: 0.7480
# Epoch 30/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3997 - accuracy: 0.8228 - val_loss: 0.5459 - val_accuracy: 0.7561
# Epoch 31/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3982 - accuracy: 0.8248 - val_loss: 0.5528 - val_accuracy: 0.7480
# Epoch 32/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3969 - accuracy: 0.8269 - val_loss: 0.5513 - val_accuracy: 0.7480
# Epoch 33/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3970 - accuracy: 0.8269 - val_loss: 0.5440 - val_accuracy: 0.7561
# Epoch 34/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3941 - accuracy: 0.8269 - val_loss: 0.5526 - val_accuracy: 0.7398
# Epoch 35/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3936 - accuracy: 0.8269 - val_loss: 0.5564 - val_accuracy: 0.7398
# Epoch 36/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3926 - accuracy: 0.8289 - val_loss: 0.5460 - val_accuracy: 0.7480
# Epoch 37/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3912 - accuracy: 0.8310 - val_loss: 0.5538 - val_accuracy: 0.7398
# Epoch 38/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3896 - accuracy: 0.8310 - val_loss: 0.5494 - val_accuracy: 0.7480
# Epoch 39/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3888 - accuracy: 0.8350 - val_loss: 0.5453 - val_accuracy: 0.7480
# Epoch 40/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3883 - accuracy: 0.8330 - val_loss: 0.5422 - val_accuracy: 0.7480
# Epoch 41/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3865 - accuracy: 0.8330 - val_loss: 0.5483 - val_accuracy: 0.7398
# Epoch 42/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3859 - accuracy: 0.8330 - val_loss: 0.5558 - val_accuracy: 0.7398
# Epoch 43/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3852 - accuracy: 0.8310 - val_loss: 0.5540 - val_accuracy: 0.7398
# Epoch 44/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3843 - accuracy: 0.8310 - val_loss: 0.5518 - val_accuracy: 0.7398
# Epoch 45/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3829 - accuracy: 0.8310 - val_loss: 0.5489 - val_accuracy: 0.7398
# Epoch 46/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3824 - accuracy: 0.8350 - val_loss: 0.5477 - val_accuracy: 0.7398
# Epoch 47/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3813 - accuracy: 0.8350 - val_loss: 0.5566 - val_accuracy: 0.7398
# Epoch 48/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3811 - accuracy: 0.8371 - val_loss: 0.5569 - val_accuracy: 0.7398
# Epoch 49/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3798 - accuracy: 0.8350 - val_loss: 0.5498 - val_accuracy: 0.7398
# Epoch 50/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3788 - accuracy: 0.8371 - val_loss: 0.5559 - val_accuracy: 0.7398
# Epoch 51/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3777 - accuracy: 0.8350 - val_loss: 0.5478 - val_accuracy: 0.7398
# Epoch 52/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3773 - accuracy: 0.8350 - val_loss: 0.5491 - val_accuracy: 0.7398
# Epoch 53/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3764 - accuracy: 0.8371 - val_loss: 0.5493 - val_accuracy: 0.7480
# Epoch 54/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3759 - accuracy: 0.8411 - val_loss: 0.5497 - val_accuracy: 0.7480
# Epoch 55/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3752 - accuracy: 0.8371 - val_loss: 0.5482 - val_accuracy: 0.7398
# Epoch 56/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3748 - accuracy: 0.8371 - val_loss: 0.5455 - val_accuracy: 0.7480
# Epoch 57/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3738 - accuracy: 0.8371 - val_loss: 0.5519 - val_accuracy: 0.7480
# Epoch 58/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3737 - accuracy: 0.8350 - val_loss: 0.5471 - val_accuracy: 0.7480
# Epoch 59/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3727 - accuracy: 0.8371 - val_loss: 0.5487 - val_accuracy: 0.7480
# Epoch 60/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3723 - accuracy: 0.8391 - val_loss: 0.5565 - val_accuracy: 0.7480
# Epoch 61/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3721 - accuracy: 0.8371 - val_loss: 0.5449 - val_accuracy: 0.7480
# Epoch 62/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3710 - accuracy: 0.8391 - val_loss: 0.5514 - val_accuracy: 0.7480
# Epoch 63/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3709 - accuracy: 0.8350 - val_loss: 0.5468 - val_accuracy: 0.7398
# Epoch 64/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3699 - accuracy: 0.8371 - val_loss: 0.5538 - val_accuracy: 0.7480
# Epoch 65/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3693 - accuracy: 0.8391 - val_loss: 0.5543 - val_accuracy: 0.7480
# Epoch 66/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3688 - accuracy: 0.8411 - val_loss: 0.5577 - val_accuracy: 0.7480
# Epoch 67/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3686 - accuracy: 0.8391 - val_loss: 0.5491 - val_accuracy: 0.7480
# Epoch 68/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3678 - accuracy: 0.8371 - val_loss: 0.5494 - val_accuracy: 0.7480
# Epoch 69/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3677 - accuracy: 0.8371 - val_loss: 0.5531 - val_accuracy: 0.7480
# Epoch 70/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3663 - accuracy: 0.8391 - val_loss: 0.5518 - val_accuracy: 0.7480
# Epoch 71/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3664 - accuracy: 0.8411 - val_loss: 0.5425 - val_accuracy: 0.7398
# Epoch 72/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3657 - accuracy: 0.8371 - val_loss: 0.5475 - val_accuracy: 0.7480
# Epoch 73/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3651 - accuracy: 0.8391 - val_loss: 0.5598 - val_accuracy: 0.7480
# Epoch 74/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3646 - accuracy: 0.8371 - val_loss: 0.5520 - val_accuracy: 0.7480
# Epoch 75/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3647 - accuracy: 0.8391 - val_loss: 0.5552 - val_accuracy: 0.7480
# Epoch 76/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3639 - accuracy: 0.8391 - val_loss: 0.5519 - val_accuracy: 0.7398
# Epoch 77/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3631 - accuracy: 0.8411 - val_loss: 0.5512 - val_accuracy: 0.7398
# Epoch 78/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3628 - accuracy: 0.8432 - val_loss: 0.5585 - val_accuracy: 0.7480
# Epoch 79/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3622 - accuracy: 0.8391 - val_loss: 0.5521 - val_accuracy: 0.7398
# Epoch 80/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3623 - accuracy: 0.8391 - val_loss: 0.5452 - val_accuracy: 0.7398
# Epoch 81/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3616 - accuracy: 0.8411 - val_loss: 0.5578 - val_accuracy: 0.7398
# Epoch 82/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3607 - accuracy: 0.8391 - val_loss: 0.5484 - val_accuracy: 0.7398
# Epoch 83/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3601 - accuracy: 0.8411 - val_loss: 0.5557 - val_accuracy: 0.7398
# Epoch 84/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3601 - accuracy: 0.8371 - val_loss: 0.5573 - val_accuracy: 0.7398
# Epoch 85/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3596 - accuracy: 0.8391 - val_loss: 0.5499 - val_accuracy: 0.7398
# Epoch 86/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3588 - accuracy: 0.8391 - val_loss: 0.5474 - val_accuracy: 0.7398
# Epoch 87/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3587 - accuracy: 0.8411 - val_loss: 0.5565 - val_accuracy: 0.7398
# Epoch 88/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3587 - accuracy: 0.8371 - val_loss: 0.5526 - val_accuracy: 0.7398
# Epoch 89/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3589 - accuracy: 0.8371 - val_loss: 0.5634 - val_accuracy: 0.7398
# Epoch 90/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3583 - accuracy: 0.8411 - val_loss: 0.5484 - val_accuracy: 0.7398
# Epoch 91/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3569 - accuracy: 0.8391 - val_loss: 0.5578 - val_accuracy: 0.7398
# Epoch 92/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3567 - accuracy: 0.8432 - val_loss: 0.5575 - val_accuracy: 0.7398
# Epoch 93/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3561 - accuracy: 0.8411 - val_loss: 0.5519 - val_accuracy: 0.7480
# Epoch 94/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3559 - accuracy: 0.8432 - val_loss: 0.5642 - val_accuracy: 0.7398
# Epoch 95/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3555 - accuracy: 0.8432 - val_loss: 0.5586 - val_accuracy: 0.7398
# Epoch 96/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3560 - accuracy: 0.8432 - val_loss: 0.5492 - val_accuracy: 0.7480
# Epoch 97/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3557 - accuracy: 0.8411 - val_loss: 0.5662 - val_accuracy: 0.7398
# Epoch 98/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3537 - accuracy: 0.8411 - val_loss: 0.5633 - val_accuracy: 0.7480
# Epoch 99/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3536 - accuracy: 0.8452 - val_loss: 0.5556 - val_accuracy: 0.7480
# Epoch 100/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3533 - accuracy: 0.8452 - val_loss: 0.5572 - val_accuracy: 0.7480
# 5/5 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#  No Diabetes       0.73      0.87      0.79        98
#     Diabetes       0.65      0.43      0.52        56
#
#     accuracy                           0.71       154
#    macro avg       0.69      0.65      0.65       154
# weighted avg       0.70      0.71      0.69       154
