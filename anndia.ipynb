# %%
# importing dataset and libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('diabetes.csv')
df.head()
df.isnull().sum()
df.duplicated()


# DATA IS CLEANED AND NOT HAVING ANY NULL AND DUPLICATED VALUES
(df['Glucose']==0).sum() # to check that is the dataset have any null value filled with zero

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())

# this dataset have values which are filled with zero
# so we have to fill them with median becuase median is not effected by outliers while mean is

zero_col = ['Glucose','BloodPressure','SkinThickness','BMI','Insulin']

for col in zero_col:
    df[col] = df[col].replace(0, df[col].median())

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())
# All the values are filled with median 
df.describe()

# splitting data into input feature and output feature
x = df.drop('Outcome',axis=1)
y = df['Outcome']


# Train Test Split

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=24,test_size=0.2)

print(x_train.shape)
print(y_train.shape)

# performing standard scalar
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# building ANN architecture 

model = Sequential()
model.add(Dense(16,activation='relu',input_shape=(8,)))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()

# compile the model 

model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# training the model;

history = model.fit(x_train,y_train,
                    epochs = 100,
                    batch_size = 32,
                    validation_split = 0.2,
                    verbose = 1
                    )



from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# Get predictions
y_pred = (model.predict(x_test) > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Diabetes', 'Diabetes'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png', dpi=150)

# Classification Report
print(classification_report(y_test, y_pred, target_names=['No Diabetes', 'Diabetes']))
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# BMI               11
# Insulin          374
# dtype: int64
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# BMI              0
# Insulin          0
# dtype: int64
# (614, 8)
# (614,)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                144
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 289
# Trainable params: 289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 1s 21ms/step - loss: 0.6940 - accuracy: 0.5438 - val_loss: 0.7028 - val_accuracy: 0.6260
# Epoch 2/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6685 - accuracy: 0.6314 - val_loss: 0.6877 - val_accuracy: 0.6504
# Epoch 3/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6455 - accuracy: 0.6864 - val_loss: 0.6746 - val_accuracy: 0.6260
# Epoch 4/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6247 - accuracy: 0.6864 - val_loss: 0.6597 - val_accuracy: 0.5935
# Epoch 5/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6030 - accuracy: 0.6945 - val_loss: 0.6451 - val_accuracy: 0.5772
# Epoch 6/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5810 - accuracy: 0.7006 - val_loss: 0.6318 - val_accuracy: 0.5691
# Epoch 7/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5598 - accuracy: 0.7169 - val_loss: 0.6176 - val_accuracy: 0.5854
# Epoch 8/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.5384 - accuracy: 0.7251 - val_loss: 0.6040 - val_accuracy: 0.5935
# Epoch 9/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5206 - accuracy: 0.7373 - val_loss: 0.5936 - val_accuracy: 0.6098
# Epoch 10/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5051 - accuracy: 0.7515 - val_loss: 0.5832 - val_accuracy: 0.6260
# Epoch 11/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4908 - accuracy: 0.7556 - val_loss: 0.5752 - val_accuracy: 0.6423
# Epoch 12/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4791 - accuracy: 0.7658 - val_loss: 0.5687 - val_accuracy: 0.6748
# Epoch 13/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4696 - accuracy: 0.7739 - val_loss: 0.5630 - val_accuracy: 0.7073
# Epoch 14/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4616 - accuracy: 0.7780 - val_loss: 0.5533 - val_accuracy: 0.7480
# Epoch 15/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4543 - accuracy: 0.7841 - val_loss: 0.5443 - val_accuracy: 0.7724
# Epoch 16/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4481 - accuracy: 0.7943 - val_loss: 0.5420 - val_accuracy: 0.7724
# Epoch 17/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4437 - accuracy: 0.7902 - val_loss: 0.5384 - val_accuracy: 0.7724
# Epoch 18/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4393 - accuracy: 0.7882 - val_loss: 0.5319 - val_accuracy: 0.7642
# Epoch 19/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4357 - accuracy: 0.7902 - val_loss: 0.5268 - val_accuracy: 0.7642
# Epoch 20/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4325 - accuracy: 0.7943 - val_loss: 0.5269 - val_accuracy: 0.7642
# Epoch 21/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4296 - accuracy: 0.7923 - val_loss: 0.5258 - val_accuracy: 0.7642
# Epoch 22/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4272 - accuracy: 0.7963 - val_loss: 0.5278 - val_accuracy: 0.7724
# Epoch 23/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4248 - accuracy: 0.7963 - val_loss: 0.5280 - val_accuracy: 0.7724
# Epoch 24/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4226 - accuracy: 0.7984 - val_loss: 0.5271 - val_accuracy: 0.7642
# Epoch 25/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4207 - accuracy: 0.7963 - val_loss: 0.5245 - val_accuracy: 0.7724
# Epoch 26/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4186 - accuracy: 0.7984 - val_loss: 0.5270 - val_accuracy: 0.7561
# Epoch 27/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4165 - accuracy: 0.7984 - val_loss: 0.5271 - val_accuracy: 0.7561
# Epoch 28/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4152 - accuracy: 0.8004 - val_loss: 0.5294 - val_accuracy: 0.7561
# Epoch 29/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4135 - accuracy: 0.8024 - val_loss: 0.5252 - val_accuracy: 0.7561
# Epoch 30/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4120 - accuracy: 0.8065 - val_loss: 0.5260 - val_accuracy: 0.7561
# Epoch 31/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4106 - accuracy: 0.8024 - val_loss: 0.5275 - val_accuracy: 0.7561
# Epoch 32/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4090 - accuracy: 0.8024 - val_loss: 0.5281 - val_accuracy: 0.7561
# Epoch 33/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4078 - accuracy: 0.8004 - val_loss: 0.5287 - val_accuracy: 0.7561
# Epoch 34/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4066 - accuracy: 0.8004 - val_loss: 0.5260 - val_accuracy: 0.7561
# Epoch 35/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4061 - accuracy: 0.8004 - val_loss: 0.5313 - val_accuracy: 0.7561
# Epoch 36/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4041 - accuracy: 0.8024 - val_loss: 0.5280 - val_accuracy: 0.7561
# Epoch 37/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4027 - accuracy: 0.8045 - val_loss: 0.5230 - val_accuracy: 0.7561
# Epoch 38/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4019 - accuracy: 0.8065 - val_loss: 0.5276 - val_accuracy: 0.7561
# Epoch 39/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4003 - accuracy: 0.8086 - val_loss: 0.5199 - val_accuracy: 0.7561
# Epoch 40/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3990 - accuracy: 0.8126 - val_loss: 0.5214 - val_accuracy: 0.7561
# Epoch 41/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3978 - accuracy: 0.8147 - val_loss: 0.5245 - val_accuracy: 0.7561
# Epoch 42/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3970 - accuracy: 0.8126 - val_loss: 0.5247 - val_accuracy: 0.7561
# Epoch 43/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3959 - accuracy: 0.8167 - val_loss: 0.5200 - val_accuracy: 0.7480
# Epoch 44/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3948 - accuracy: 0.8126 - val_loss: 0.5204 - val_accuracy: 0.7480
# Epoch 45/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3936 - accuracy: 0.8126 - val_loss: 0.5191 - val_accuracy: 0.7480
# Epoch 46/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3930 - accuracy: 0.8147 - val_loss: 0.5221 - val_accuracy: 0.7480
# Epoch 47/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3918 - accuracy: 0.8147 - val_loss: 0.5161 - val_accuracy: 0.7480
# Epoch 48/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3907 - accuracy: 0.8147 - val_loss: 0.5168 - val_accuracy: 0.7398
# Epoch 49/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3897 - accuracy: 0.8187 - val_loss: 0.5212 - val_accuracy: 0.7480
# Epoch 50/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3889 - accuracy: 0.8228 - val_loss: 0.5276 - val_accuracy: 0.7480
# Epoch 51/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3880 - accuracy: 0.8228 - val_loss: 0.5200 - val_accuracy: 0.7480
# Epoch 52/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3872 - accuracy: 0.8208 - val_loss: 0.5174 - val_accuracy: 0.7561
# Epoch 53/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3866 - accuracy: 0.8228 - val_loss: 0.5169 - val_accuracy: 0.7480
# Epoch 54/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3852 - accuracy: 0.8208 - val_loss: 0.5165 - val_accuracy: 0.7480
# Epoch 55/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3848 - accuracy: 0.8228 - val_loss: 0.5231 - val_accuracy: 0.7398
# Epoch 56/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3838 - accuracy: 0.8228 - val_loss: 0.5200 - val_accuracy: 0.7480
# Epoch 57/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3830 - accuracy: 0.8228 - val_loss: 0.5179 - val_accuracy: 0.7480
# Epoch 58/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3832 - accuracy: 0.8187 - val_loss: 0.5132 - val_accuracy: 0.7480
# Epoch 59/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3823 - accuracy: 0.8187 - val_loss: 0.5160 - val_accuracy: 0.7480
# Epoch 60/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3813 - accuracy: 0.8228 - val_loss: 0.5194 - val_accuracy: 0.7480
# Epoch 61/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3805 - accuracy: 0.8248 - val_loss: 0.5228 - val_accuracy: 0.7561
# Epoch 62/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3807 - accuracy: 0.8208 - val_loss: 0.5180 - val_accuracy: 0.7480
# Epoch 63/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3793 - accuracy: 0.8228 - val_loss: 0.5150 - val_accuracy: 0.7480
# Epoch 64/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3782 - accuracy: 0.8228 - val_loss: 0.5186 - val_accuracy: 0.7480
# Epoch 65/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3773 - accuracy: 0.8248 - val_loss: 0.5182 - val_accuracy: 0.7480
# Epoch 66/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3769 - accuracy: 0.8248 - val_loss: 0.5184 - val_accuracy: 0.7480
# Epoch 67/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3765 - accuracy: 0.8289 - val_loss: 0.5214 - val_accuracy: 0.7480
# Epoch 68/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3761 - accuracy: 0.8289 - val_loss: 0.5172 - val_accuracy: 0.7480
# Epoch 69/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3749 - accuracy: 0.8269 - val_loss: 0.5195 - val_accuracy: 0.7398
# Epoch 70/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3742 - accuracy: 0.8269 - val_loss: 0.5258 - val_accuracy: 0.7480
# Epoch 71/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3736 - accuracy: 0.8269 - val_loss: 0.5257 - val_accuracy: 0.7398
# Epoch 72/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3733 - accuracy: 0.8289 - val_loss: 0.5268 - val_accuracy: 0.7480
# Epoch 73/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3727 - accuracy: 0.8248 - val_loss: 0.5166 - val_accuracy: 0.7317
# Epoch 74/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.3719 - accuracy: 0.8248 - val_loss: 0.5193 - val_accuracy: 0.7398
# Epoch 75/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3715 - accuracy: 0.8269 - val_loss: 0.5273 - val_accuracy: 0.7480
# Epoch 76/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3706 - accuracy: 0.8228 - val_loss: 0.5209 - val_accuracy: 0.7398
# Epoch 77/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3701 - accuracy: 0.8248 - val_loss: 0.5288 - val_accuracy: 0.7480
# Epoch 78/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3686 - accuracy: 0.8269 - val_loss: 0.5208 - val_accuracy: 0.7480
# Epoch 79/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3684 - accuracy: 0.8269 - val_loss: 0.5188 - val_accuracy: 0.7480
# Epoch 80/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3677 - accuracy: 0.8269 - val_loss: 0.5202 - val_accuracy: 0.7480
# Epoch 81/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3672 - accuracy: 0.8289 - val_loss: 0.5166 - val_accuracy: 0.7480
# Epoch 82/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3669 - accuracy: 0.8289 - val_loss: 0.5269 - val_accuracy: 0.7480
# Epoch 83/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3663 - accuracy: 0.8289 - val_loss: 0.5303 - val_accuracy: 0.7480
# Epoch 84/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3655 - accuracy: 0.8289 - val_loss: 0.5233 - val_accuracy: 0.7480
# Epoch 85/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3650 - accuracy: 0.8310 - val_loss: 0.5300 - val_accuracy: 0.7480
# Epoch 86/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3640 - accuracy: 0.8330 - val_loss: 0.5246 - val_accuracy: 0.7480
# Epoch 87/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3638 - accuracy: 0.8310 - val_loss: 0.5253 - val_accuracy: 0.7480
# Epoch 88/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3630 - accuracy: 0.8310 - val_loss: 0.5321 - val_accuracy: 0.7480
# Epoch 89/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3627 - accuracy: 0.8330 - val_loss: 0.5341 - val_accuracy: 0.7480
# Epoch 90/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3616 - accuracy: 0.8330 - val_loss: 0.5228 - val_accuracy: 0.7480
# Epoch 91/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3608 - accuracy: 0.8350 - val_loss: 0.5270 - val_accuracy: 0.7480
# Epoch 92/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3612 - accuracy: 0.8371 - val_loss: 0.5336 - val_accuracy: 0.7480
# Epoch 93/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3603 - accuracy: 0.8350 - val_loss: 0.5265 - val_accuracy: 0.7480
# Epoch 94/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3592 - accuracy: 0.8330 - val_loss: 0.5298 - val_accuracy: 0.7480
# Epoch 95/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3587 - accuracy: 0.8330 - val_loss: 0.5241 - val_accuracy: 0.7480
# Epoch 96/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3585 - accuracy: 0.8289 - val_loss: 0.5237 - val_accuracy: 0.7480
# Epoch 97/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3578 - accuracy: 0.8371 - val_loss: 0.5253 - val_accuracy: 0.7398
# Epoch 98/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3577 - accuracy: 0.8350 - val_loss: 0.5266 - val_accuracy: 0.7398
# Epoch 99/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3569 - accuracy: 0.8371 - val_loss: 0.5299 - val_accuracy: 0.7398
# Epoch 100/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3563 - accuracy: 0.8371 - val_loss: 0.5324 - val_accuracy: 0.7398
# 5/5 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#  No Diabetes       0.72      0.86      0.79        98
#     Diabetes       0.63      0.43      0.51        56
#
#     accuracy                           0.70       154
#    macro avg       0.68      0.64      0.65       154
# weighted avg       0.69      0.70      0.69       154

# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
print(np.__version__)
# Out:
# 2.10.1
# 1.26.4
