# %%
# importing dataset and libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('diabetes.csv')
df.head()
df.isnull().sum()
df.duplicated()


# DATA IS CLEANED AND NOT HAVING ANY NULL AND DUPLICATED VALUES
(df['Glucose']==0).sum() # to check that is the dataset have any null value filled with zero

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())

# this dataset have values which are filled with zero
# so we have to fill them with median becuase median is not effected by outliers while mean is

zero_col = ['Glucose','BloodPressure','SkinThickness','BMI','Insulin']

for col in zero_col:
    df[col] = df[col].replace(0, df[col].median())

print(df[['Glucose','BloodPressure','SkinThickness','BMI','Insulin',]].eq(0).sum())
# All the values are filled with median 
df.describe()

# splitting data into input feature and output feature
x = df.drop('Outcome',axis=1)
y = df['Outcome']


# Train Test Split

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=24,test_size=0.2)

print(x_train.shape)
print(y_train.shape)

# performing standard scalar
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# building ANN architecture 

model = Sequential()
model.add(Dense(16,activation='relu',input_shape=(8,)))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()

# compile the model 

model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# training the model;

history = model.fit(x_train,y_train,
                    epochs = 100,
                    batch_size = 256,
                    validation_split = 0.2,
                    verbose = 1
                    )



from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# Get predictions
y_pred = (model.predict(x_test) > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Diabetes', 'Diabetes'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png', dpi=150)

# Classification Report
print(classification_report(y_test, y_pred, target_names=['No Diabetes', 'Diabetes']))
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# BMI               11
# Insulin          374
# dtype: int64
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# BMI              0
# Insulin          0
# dtype: int64
# (614, 8)
# (614,)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 16)                144
#
#  dense_22 (Dense)            (None, 8)                 136
#
#  dense_23 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 289
# Trainable params: 289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.7785 - accuracy: 0.4175 - val_loss: 0.6614 - val_accuracy: 0.5935
# Epoch 2/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.7659 - accuracy: 0.4318 - val_loss: 0.6563 - val_accuracy: 0.5935
# Epoch 3/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7533 - accuracy: 0.4603 - val_loss: 0.6516 - val_accuracy: 0.5935
# Epoch 4/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7418 - accuracy: 0.4766 - val_loss: 0.6473 - val_accuracy: 0.6098
# Epoch 5/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7306 - accuracy: 0.4908 - val_loss: 0.6432 - val_accuracy: 0.6260
# Epoch 6/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7199 - accuracy: 0.5051 - val_loss: 0.6393 - val_accuracy: 0.6260
# Epoch 7/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7096 - accuracy: 0.5275 - val_loss: 0.6356 - val_accuracy: 0.6260
# Epoch 8/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.7000 - accuracy: 0.5356 - val_loss: 0.6323 - val_accuracy: 0.6341
# Epoch 9/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6902 - accuracy: 0.5519 - val_loss: 0.6292 - val_accuracy: 0.6423
# Epoch 10/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6813 - accuracy: 0.5601 - val_loss: 0.6263 - val_accuracy: 0.6504
# Epoch 11/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6728 - accuracy: 0.5703 - val_loss: 0.6237 - val_accuracy: 0.6504
# Epoch 12/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6646 - accuracy: 0.5906 - val_loss: 0.6212 - val_accuracy: 0.6748
# Epoch 13/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6567 - accuracy: 0.6069 - val_loss: 0.6186 - val_accuracy: 0.6748
# Epoch 14/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6491 - accuracy: 0.6354 - val_loss: 0.6160 - val_accuracy: 0.6748
# Epoch 15/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6417 - accuracy: 0.6619 - val_loss: 0.6135 - val_accuracy: 0.6667
# Epoch 16/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6350 - accuracy: 0.6802 - val_loss: 0.6111 - val_accuracy: 0.6667
# Epoch 17/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6281 - accuracy: 0.6823 - val_loss: 0.6087 - val_accuracy: 0.6829
# Epoch 18/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6218 - accuracy: 0.7026 - val_loss: 0.6065 - val_accuracy: 0.6829
# Epoch 19/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6152 - accuracy: 0.7088 - val_loss: 0.6042 - val_accuracy: 0.6748
# Epoch 20/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6091 - accuracy: 0.7210 - val_loss: 0.6020 - val_accuracy: 0.6992
# Epoch 21/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6034 - accuracy: 0.7312 - val_loss: 0.5999 - val_accuracy: 0.7073
# Epoch 22/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5974 - accuracy: 0.7434 - val_loss: 0.5975 - val_accuracy: 0.7073
# Epoch 23/100
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5917 - accuracy: 0.7475 - val_loss: 0.5953 - val_accuracy: 0.7073
# Epoch 24/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5863 - accuracy: 0.7475 - val_loss: 0.5928 - val_accuracy: 0.7073
# Epoch 25/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5812 - accuracy: 0.7475 - val_loss: 0.5904 - val_accuracy: 0.6992
# Epoch 26/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5761 - accuracy: 0.7475 - val_loss: 0.5880 - val_accuracy: 0.6992
# Epoch 27/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5710 - accuracy: 0.7536 - val_loss: 0.5856 - val_accuracy: 0.6992
# Epoch 28/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5662 - accuracy: 0.7576 - val_loss: 0.5830 - val_accuracy: 0.6911
# Epoch 29/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5613 - accuracy: 0.7556 - val_loss: 0.5806 - val_accuracy: 0.6992
# Epoch 30/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5566 - accuracy: 0.7556 - val_loss: 0.5781 - val_accuracy: 0.6992
# Epoch 31/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5520 - accuracy: 0.7515 - val_loss: 0.5759 - val_accuracy: 0.7073
# Epoch 32/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5476 - accuracy: 0.7556 - val_loss: 0.5735 - val_accuracy: 0.7073
# Epoch 33/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5433 - accuracy: 0.7637 - val_loss: 0.5712 - val_accuracy: 0.7073
# Epoch 34/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5390 - accuracy: 0.7658 - val_loss: 0.5688 - val_accuracy: 0.7073
# Epoch 35/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5351 - accuracy: 0.7678 - val_loss: 0.5665 - val_accuracy: 0.7073
# Epoch 36/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5311 - accuracy: 0.7699 - val_loss: 0.5643 - val_accuracy: 0.7073
# Epoch 37/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5271 - accuracy: 0.7699 - val_loss: 0.5620 - val_accuracy: 0.7154
# Epoch 38/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5233 - accuracy: 0.7699 - val_loss: 0.5600 - val_accuracy: 0.7154
# Epoch 39/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5198 - accuracy: 0.7719 - val_loss: 0.5578 - val_accuracy: 0.7154
# Epoch 40/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5162 - accuracy: 0.7800 - val_loss: 0.5559 - val_accuracy: 0.7073
# Epoch 41/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5127 - accuracy: 0.7800 - val_loss: 0.5540 - val_accuracy: 0.7073
# Epoch 42/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5094 - accuracy: 0.7821 - val_loss: 0.5522 - val_accuracy: 0.7073
# Epoch 43/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5062 - accuracy: 0.7841 - val_loss: 0.5504 - val_accuracy: 0.7073
# Epoch 44/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5029 - accuracy: 0.7862 - val_loss: 0.5486 - val_accuracy: 0.7073
# Epoch 45/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4999 - accuracy: 0.7841 - val_loss: 0.5469 - val_accuracy: 0.7073
# Epoch 46/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4968 - accuracy: 0.7862 - val_loss: 0.5453 - val_accuracy: 0.7073
# Epoch 47/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4940 - accuracy: 0.7862 - val_loss: 0.5439 - val_accuracy: 0.7073
# Epoch 48/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4912 - accuracy: 0.7862 - val_loss: 0.5424 - val_accuracy: 0.7154
# Epoch 49/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4885 - accuracy: 0.7862 - val_loss: 0.5410 - val_accuracy: 0.7154
# Epoch 50/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4861 - accuracy: 0.7902 - val_loss: 0.5396 - val_accuracy: 0.7154
# Epoch 51/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4834 - accuracy: 0.7902 - val_loss: 0.5382 - val_accuracy: 0.7154
# Epoch 52/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4811 - accuracy: 0.7923 - val_loss: 0.5372 - val_accuracy: 0.7154
# Epoch 53/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4787 - accuracy: 0.7923 - val_loss: 0.5361 - val_accuracy: 0.7154
# Epoch 54/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4764 - accuracy: 0.7923 - val_loss: 0.5350 - val_accuracy: 0.7154
# Epoch 55/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4742 - accuracy: 0.7943 - val_loss: 0.5340 - val_accuracy: 0.7073
# Epoch 56/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4722 - accuracy: 0.7984 - val_loss: 0.5331 - val_accuracy: 0.7073
# Epoch 57/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4702 - accuracy: 0.8004 - val_loss: 0.5322 - val_accuracy: 0.7073
# Epoch 58/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4683 - accuracy: 0.8024 - val_loss: 0.5312 - val_accuracy: 0.7073
# Epoch 59/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4664 - accuracy: 0.8024 - val_loss: 0.5305 - val_accuracy: 0.7154
# Epoch 60/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4645 - accuracy: 0.8045 - val_loss: 0.5296 - val_accuracy: 0.7236
# Epoch 61/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4629 - accuracy: 0.8045 - val_loss: 0.5291 - val_accuracy: 0.7236
# Epoch 62/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4612 - accuracy: 0.8024 - val_loss: 0.5284 - val_accuracy: 0.7236
# Epoch 63/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4596 - accuracy: 0.8024 - val_loss: 0.5277 - val_accuracy: 0.7317
# Epoch 64/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4579 - accuracy: 0.8024 - val_loss: 0.5269 - val_accuracy: 0.7236
# Epoch 65/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4564 - accuracy: 0.8024 - val_loss: 0.5265 - val_accuracy: 0.7236
# Epoch 66/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4550 - accuracy: 0.8045 - val_loss: 0.5260 - val_accuracy: 0.7236
# Epoch 67/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4536 - accuracy: 0.8065 - val_loss: 0.5256 - val_accuracy: 0.7236
# Epoch 68/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4522 - accuracy: 0.8065 - val_loss: 0.5251 - val_accuracy: 0.7236
# Epoch 69/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4509 - accuracy: 0.8086 - val_loss: 0.5248 - val_accuracy: 0.7236
# Epoch 70/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4495 - accuracy: 0.8086 - val_loss: 0.5244 - val_accuracy: 0.7236
# Epoch 71/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4484 - accuracy: 0.8106 - val_loss: 0.5242 - val_accuracy: 0.7236
# Epoch 72/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4472 - accuracy: 0.8106 - val_loss: 0.5241 - val_accuracy: 0.7236
# Epoch 73/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4460 - accuracy: 0.8106 - val_loss: 0.5239 - val_accuracy: 0.7317
# Epoch 74/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4450 - accuracy: 0.8106 - val_loss: 0.5236 - val_accuracy: 0.7317
# Epoch 75/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4438 - accuracy: 0.8126 - val_loss: 0.5232 - val_accuracy: 0.7317
# Epoch 76/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4428 - accuracy: 0.8106 - val_loss: 0.5230 - val_accuracy: 0.7317
# Epoch 77/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4418 - accuracy: 0.8106 - val_loss: 0.5228 - val_accuracy: 0.7317
# Epoch 78/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4408 - accuracy: 0.8106 - val_loss: 0.5225 - val_accuracy: 0.7317
# Epoch 79/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4399 - accuracy: 0.8126 - val_loss: 0.5226 - val_accuracy: 0.7317
# Epoch 80/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4389 - accuracy: 0.8126 - val_loss: 0.5226 - val_accuracy: 0.7317
# Epoch 81/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4380 - accuracy: 0.8126 - val_loss: 0.5224 - val_accuracy: 0.7317
# Epoch 82/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4372 - accuracy: 0.8147 - val_loss: 0.5223 - val_accuracy: 0.7398
# Epoch 83/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4364 - accuracy: 0.8126 - val_loss: 0.5221 - val_accuracy: 0.7398
# Epoch 84/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4356 - accuracy: 0.8106 - val_loss: 0.5219 - val_accuracy: 0.7398
# Epoch 85/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4348 - accuracy: 0.8106 - val_loss: 0.5218 - val_accuracy: 0.7398
# Epoch 86/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4340 - accuracy: 0.8126 - val_loss: 0.5217 - val_accuracy: 0.7398
# Epoch 87/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4332 - accuracy: 0.8126 - val_loss: 0.5216 - val_accuracy: 0.7398
# Epoch 88/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4326 - accuracy: 0.8126 - val_loss: 0.5213 - val_accuracy: 0.7398
# Epoch 89/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4319 - accuracy: 0.8147 - val_loss: 0.5213 - val_accuracy: 0.7398
# Epoch 90/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4312 - accuracy: 0.8147 - val_loss: 0.5212 - val_accuracy: 0.7480
# Epoch 91/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4305 - accuracy: 0.8147 - val_loss: 0.5211 - val_accuracy: 0.7480
# Epoch 92/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4299 - accuracy: 0.8167 - val_loss: 0.5211 - val_accuracy: 0.7480
# Epoch 93/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.4293 - accuracy: 0.8187 - val_loss: 0.5210 - val_accuracy: 0.7480
# Epoch 94/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4287 - accuracy: 0.8187 - val_loss: 0.5211 - val_accuracy: 0.7480
# Epoch 95/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4280 - accuracy: 0.8187 - val_loss: 0.5211 - val_accuracy: 0.7480
# Epoch 96/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4274 - accuracy: 0.8187 - val_loss: 0.5210 - val_accuracy: 0.7480
# Epoch 97/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4269 - accuracy: 0.8187 - val_loss: 0.5210 - val_accuracy: 0.7480
# Epoch 98/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4263 - accuracy: 0.8187 - val_loss: 0.5208 - val_accuracy: 0.7480
# Epoch 99/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4257 - accuracy: 0.8208 - val_loss: 0.5209 - val_accuracy: 0.7480
# Epoch 100/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4252 - accuracy: 0.8208 - val_loss: 0.5209 - val_accuracy: 0.7480
# 5/5 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#  No Diabetes       0.71      0.92      0.80        98
#     Diabetes       0.71      0.36      0.48        56
#
#     accuracy                           0.71       154
#    macro avg       0.71      0.64      0.64       154
# weighted avg       0.71      0.71      0.68       154

# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
print(np.__version__)
# Out:
# 2.10.1
# 1.26.4
