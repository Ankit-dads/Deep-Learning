# %%
import seaborn as sns               # To load the tips dataset
import pandas as pd                 # To work with data tables (DataFrames)
import numpy as np                  # For math operations
import matplotlib.pyplot as plt     # To draw graphs

from sklearn.model_selection import train_test_split  # To split data
from sklearn.linear_model import LinearRegression      # Our ML model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ASUS\.conda\envs\py3.9\python.exe

# %%
import tensorflow as tf
print(tf)
# Out:
# <module 'tensorflow' from 'c:\\Users\\ASUS\\.conda\\envs\\py3.9\\lib\\site-packages\\tensorflow\\__init__.py'>

# %%
print(tf.__version__)
# Out:
# 2.10.1

# %%
import tensorflow as tf

print("TF Version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
print("Is GPU Available:", tf.test.is_gpu_available())
# Out:
# TF Version: 2.10.1
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Is GPU Available: True
